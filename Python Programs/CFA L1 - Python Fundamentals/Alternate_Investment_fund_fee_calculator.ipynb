# %%
Bgn_value = []
management_fee = []
incentive_fee = []
end_value = []

# %%
#input all variables


initial_investment = int(input("Enter intial investment amount : "))
mgmt_fee = float(input("Enter the management fee in decimals : "))
Calc_on= input("Management fee is calculated on Beginning(B) AUM or Ending (E) AUM \n Enter 'B' or 'E' : ")
hurdle = float(input("Enter the hurdle rate : "))
h_type = input("Is it a soft(S) hurdle rate or a hard(H) hudle rate \n Enter S or H : ")

end_value.append(initial_investment)

# %%
def mgmt_fee_calculation(mgmt_fee, Ending_or_bgn,bgn,gross_return):
    if Ending_or_bgn == "B":
        return  mgmt_fee * (bgn)
    else :
        return mgmt_fee * (1 + gross_return) * bgn

# %%
def incentive_fee_calculation(bgn,HWM,rate,type,Gross_return,incentive_rate)
    Gross_return_abs = bgn * ( 1 + Gross_return)
    if  Gross_return_abs > HWM:
        if type == "S":
            fees = ((Gross_return_abs - HWM ) * incentive_rate)
        elif type == "H":
            fees = (Gross_return_abs - (HWM * (1 + rate))) * (incentive_rate)
    elif Gross_return_abs <= HWM:
        fees = 0 
        
    return fees

# %%
def calculation_of_End_of_fund_value(bgn_balance, gross_return,total_fee):
    return (((bgn_balance *(1 + gross_return)-(total_fee))))

# %%
initial_investment = int(input("Enter intial investment amount : "))
mgmt_fee = float(input("Enter the management fee in decimals : "))
Calc_on= input("Management fee is calculated on Beginning(B) AUM or Ending (E) AUM \n Enter 'B' or 'E' : ")
hurdle = float(input("Enter the hurdle rate : "))
h_type = input("Is it a soft(S) hurdle rate or a hard(H) hudle rate \n Enter S or H : ")
incentive_rate = float(input("Enter the rate of incentive fee in decimals : "))
more_years = "Y"

Bgn_value.append(initial_investment)
while more_years == "Y":
    high_watermark = max(end_value)
    gross_return = float(input("Enter gross return in decimals : "))
    total_fees = mgmt_fee_calculation(mgmt_fee,Calc_on,Bgn_value[-1],gross_return) + incentive_fee_calculation(Bgn_value[-1],high_watermark,hurdle,h_type,gross_return,incentive_rate)

    calculation_of_End_of_fund_value(Bgn_value[-1],gross_return,total_fees)
    #addinf fund valueS to the table 

end_value.append(calculation_of_End_of_fund_value)
mgm
