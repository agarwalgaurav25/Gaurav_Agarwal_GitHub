# %%
import random 
import numpy as np
import plotly.express as px
import pandas as pd

# %%
#Random weight generator
def random_weight_generator(n):
    weights = []
    for i in range(n):
        weights.append(random.random())
    weights = weights/ np.sum(weights)
    return weights

# %%
#Function to assign weights

def assign_weights(stocklist):
    weights = random_weight_generator(len(stocklist))
    weight_stock_dic = {}
    for i in range(len(stocklist)):
        weight_stock_dic[stocklist[i]] = weights[i]

    print (weight_stock_dic)

# %%
#Function to scale the prices 
def price_scaling(raw_prices_df):
    scaled_prices_df = raw_prices_df.copy()
    for i in raw_prices_df.columns[1:]:
        scaled_prices_df[i] = raw_prices_df[i]/raw_prices_df[i][0]
    return scaled_prices_df

# %%
weights = random_weight_generator(10) if np.sum( random_weight_generator(10)) == 1 else "Sum is not 1"
print (weights)
# Out:
# [0.01373925 0.08767389 0.11785924 0.02128941 0.08870968 0.22644688
#  0.0545006  0.19385862 0.10973693 0.08618549]

# %%
assign_weights(stocks)
# Out:
# {'AMZ': np.float64(0.05202266955198992), 'JPM': np.float64(0.2411941775933964), 'DE': np.float64(0.7067831528546137)}

# %%
weights = [0.032266, 0.094461, 0.117917, 0.132624, 0.145942, 0.128299, 0.10009, 0.007403, 0.088581, 0.152417]

# %%
close_prices_df = pd.read_csv('stock_prices.csv')
close_prices_df
# Out:
#             Date       AMZN         CAT          DE        EXC      GOOGL  \
# 0       1/2/2014  19.898500   69.512543   75.620926  14.121004  27.855856
# 1       1/3/2014  19.822001   69.473892   75.956062  13.835152  27.652653
# 2       1/6/2014  19.681499   68.561180   75.327690  13.923512  27.960960
# 3       1/7/2014  19.901501   68.785461   75.662811  13.996271  28.500000
# 4       1/8/2014  20.096001   68.947906   74.850121  13.965082  28.559309
# ...          ...        ...         ...         ...        ...        ...
# 2252  12/12/2022  90.550003  233.059998  437.049988  42.500000  93.309998
# 2253  12/13/2022  92.489998  235.490005  437.190002  42.540001  95.629997
# 2254  12/14/2022  91.580002  234.479996  438.440002  42.820000  95.070000
# 2255  12/15/2022  88.449997  230.660004  429.790008  42.380001  90.860001
# 2256  12/16/2022  87.860001  232.720001  431.089996  41.930000  90.260002
#
#              JNJ         JPM        META        PFE          PG
# 0      71.443314   45.640057   54.709999  20.879053   61.941517
# 1      72.086861   45.992889   54.560001  20.920183   61.872295
# 2      72.463608   46.259468   57.200001  20.940746   62.018425
# 3      74.001869   45.726311   57.919998  21.070980   62.618301
# 4      73.899841   46.157543   58.230000  21.214928   61.710812
# ...          ...         ...         ...        ...         ...
# 2252  177.839996  134.210007  114.709999  52.160000  152.470001
# 2253  179.210007  134.080002  120.150002  53.070000  152.240005
# 2254  179.759995  133.410004  121.589996  54.480000  152.839996
# 2255  177.490005  130.100006  116.150002  53.610001  151.110001
# 2256  175.669998  129.289993  119.430000  51.400002  150.440002
#
# [2257 rows x 11 columns]

# %%
portfolio_df = close_prices_df.copy()
scaled_df = price_scaling(portfolio_df)
scaled_df
# Out:
#             Date      AMZN       CAT        DE       EXC     GOOGL       JNJ  \
# 0       1/2/2014  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1       1/3/2014  0.996155  0.999444  1.004432  0.979757  0.992705  1.009008
# 2       1/6/2014  0.989095  0.986314  0.996122  0.986014  1.003773  1.014281
# 3       1/7/2014  1.000151  0.989540  1.000554  0.991167  1.023124  1.035812
# 4       1/8/2014  1.009925  0.991877  0.989807  0.988958  1.025253  1.034384
# ...          ...       ...       ...       ...       ...       ...       ...
# 2252  12/12/2022  4.550594  3.352776  5.779485  3.009701  3.349744  2.489246
# 2253  12/13/2022  4.648089  3.387734  5.781336  3.012534  3.433030  2.508422
# 2254  12/14/2022  4.602357  3.373204  5.797866  3.032362  3.412927  2.516121
# 2255  12/15/2022  4.445058  3.318250  5.683480  3.001203  3.261792  2.484347
# 2256  12/16/2022  4.415408  3.347885  5.700671  2.969336  3.240252  2.458872
#
#            JPM      META       PFE        PG
# 0     1.000000  1.000000  1.000000  1.000000
# 1     1.007731  0.997258  1.001970  0.998882
# 2     1.013572  1.045513  1.002955  1.001242
# 3     1.001890  1.058673  1.009192  1.010926
# 4     1.011338  1.064339  1.016087  0.996275
# ...        ...       ...       ...       ...
# 2252  2.940619  2.096692  2.498198  2.461515
# 2253  2.937770  2.196125  2.541782  2.457802
# 2254  2.923090  2.222446  2.609314  2.467489
# 2255  2.850566  2.123012  2.567645  2.439559
# 2256  2.832818  2.182965  2.461798  2.428743
#
# [2257 rows x 11 columns]

# %%
initial_investment = float(100000)

for i, stock in enumerate(scaled_df.columns[1:]):
    portfolio_df[stock] = weights[i] * scaled_df[stock] * initial_investment

portfolio_df.round(1)
# Out:
#             Date     AMZN      CAT       DE      EXC    GOOGL      JNJ  \
# 0       1/2/2014   3226.6   9446.1  11791.7  13262.4  14594.2  12829.9
# 1       1/3/2014   3214.2   9440.8  11844.0  12993.9  14487.7  12945.5
# 2       1/6/2014   3191.4   9316.8  11746.0  13076.9  14649.3  13013.1
# 3       1/7/2014   3227.1   9347.3  11798.2  13145.3  14931.7  13289.4
# 4       1/8/2014   3258.6   9369.4  11671.5  13116.0  14962.8  13271.0
# ...          ...      ...      ...      ...      ...      ...      ...
# 2252  12/12/2022  14682.9  31670.7  68150.0  39915.9  48886.8  31936.8
# 2253  12/13/2022  14997.5  32000.9  68171.8  39953.4  50102.3  32182.8
# 2254  12/14/2022  14850.0  31863.6  68366.7  40216.4  49808.9  32281.6
# 2255  12/15/2022  14342.4  31344.5  67017.9  39803.2  47603.2  31873.9
# 2256  12/16/2022  14246.8  31624.5  67220.6  39380.5  47288.9  31547.1
#
#           JPM    META      PFE       PG
# 0     10009.0   740.3   8858.1  15241.7
# 1     10086.4   738.3   8875.5  15224.7
# 2     10144.8   774.0   8884.3  15260.6
# 3     10027.9   783.7   8939.5  15408.2
# 4     10122.5   787.9   9000.6  15184.9
# ...       ...     ...      ...      ...
# 2252  29432.7  1552.2  22129.3  37517.7
# 2253  29404.1  1625.8  22515.4  37461.1
# 2254  29257.2  1645.3  23113.6  37608.7
# 2255  28531.3  1571.7  22744.5  37183.0
# 2256  28353.7  1616.0  21806.8  37018.2
#
# [2257 rows x 11 columns]

# %%
def asset_allocation ( df, weights, initial_investment):
    portfolio_df= df.copy()

    scaled_df = price_scaling(portfolio_df)

    for i , stock in enumerate ( portfolio_df.columns[1:]):
        portfolio_df[stock] = weights[i] * scaled_df[stock] * initial_investment

    portfolio_df['Value of Portfolio'] = portfolio_df[portfolio_df != 'Date'].sum(axis = 1 , numeric_only = True)

   
    portfolio_df['Daily pct change'] = portfolio_df['Value of Portfolio'].pct_change(1) * 100
    portfolio_df.replace(np.nan , 0 , inplace = True)

    return portfolio_df

# %%
#function to plot a graph
def plot_financial_graph(df,title):
  fig = px.line(title = title)

  for i in df.columns[1:]:
    fig.add_scatter( x = df['Date'] , y = df[i], name = i )
    fig.update_traces(line_width = 5)
    fig.update_layout({'plot_bgcolor' : 'white'})
  fig.show()

# %%
def simulation_engine(weights,initial_investment):
    portfolio_df =  asset_allocation(close_prices_df,weights,initial_investment)

    return_on_investment =( ((portfolio_df['Value of Portfolio'][-1:])/ (portfolio_df['Value of Portfolio'][0])) - 1 )*100

    portfolio_daily_return_df = portfolio_df.drop(columns = ['Date','Value of Portfolio', 'Daily pct change'])
    portfolio_daily_return_df = portfolio_daily_return_df.pct_change(1)

    expected_portfolio_return = np.sum(weights * portfolio_daily_return_df.mean()) * 252

    covariance = portfolio_daily_return_df.cov() * 252
    expected_volatility = np.sqrt(np.dot(weights.T, np.dot(covariance, weights)))

    rf = .035

    sharpe_ratio = expected_portfolio_return - rf / expected_volatility

    return expected_portfolio_return, expected_volatility, sharpe_ratio, portfolio_df['Value of Portfolio'][-1:].values[0], return_on_investment.values[0]

# %%
n = len(close_prices_df.columns) - 1 

print (f'The number of stocks = {n}')
weights = random_weight_generator(n)

portfolio_df= asset_allocation(close_prices_df,weights,1000000)
portfolio_df.round(2)
# Out:
# The number of stocks = 10
#             Date       AMZN        CAT         DE        EXC      GOOGL  \
# 0       1/2/2014   85392.72  187813.01  114797.39  151143.02  183981.23
# 1       1/3/2014   85064.43  187708.59  115306.15  148083.43  182639.13
# 2       1/6/2014   84461.48  185242.57  114352.24  149029.18  184675.42
# 3       1/7/2014   85405.59  185848.54  114860.98  149807.95  188235.65
# 4       1/8/2014   86240.27  186287.45  113627.26  149474.13  188627.37
# ...          ...        ...        ...        ...        ...        ...
# 2252  12/12/2022  388587.62  629695.00  663469.77  454895.31  616290.11
# 2253  12/13/2022  396912.95  636260.54  663682.32  455323.45  631613.15
# 2254  12/14/2022  393007.78  633531.64  665579.90  458320.40  627914.50
# 2255  12/15/2022  379575.63  623210.56  652448.66  453610.91  600108.47
# 2256  12/16/2022  377043.71  628776.38  654422.12  448794.36  596145.62
#
#             JNJ        JPM      META        PFE         PG  \
# 0      55245.06   51692.47  12495.27  116298.23   41141.59
# 1      55742.70   52092.09  12461.01  116527.33   41095.61
# 2      56034.03   52394.02  13063.96  116641.87   41192.67
# 3      57223.52   51790.16  13228.40  117367.28   41591.11
# 4      57144.63   52278.58  13299.20  118169.08   40988.35
# ...         ...        ...       ...        ...        ...
# 2252  137518.57  152007.84  26198.72  290535.96  101270.65
# 2253  138577.95  151860.60  27441.17  295604.74  101117.88
# 2254  139003.24  151101.75  27770.05  303458.57  101516.40
# 2255  137247.93  147352.81  26527.61  298612.60  100367.33
# 2256  135840.57  146435.38  27276.73  286302.70   99922.32
#
#       Value of Portfolio  Daily pct change
# 0             1000000.00              0.00
# 1              996720.45             -0.33
# 2              997087.44              0.04
# 3             1005359.19              0.83
# 4             1006136.32              0.08
# ...                  ...               ...
# 2252          3460469.55              1.38
# 2253          3498394.76              1.10
# 2254          3501204.23              0.08
# 2255          3419062.50             -2.35
# 2256          3400959.89             -0.53
#
# [2257 rows x 13 columns]

# %%
portfolio_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2257 entries, 0 to 2256
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                2257 non-null   object
#  1   AMZN                2257 non-null   float64
#  2   CAT                 2257 non-null   float64
#  3   DE                  2257 non-null   float64
#  4   EXC                 2257 non-null   float64
#  5   GOOGL               2257 non-null   float64
#  6   JNJ                 2257 non-null   float64
#  7   JPM                 2257 non-null   float64
#  8   META                2257 non-null   float64
#  9   PFE                 2257 non-null   float64
#  10  PG                  2257 non-null   float64
#  11  Value of Portfolio  2257 non-null   float64
#  12  Daily pct change    2257 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 229.4+ KB

# %%
plot_financial_graph(scaled_df,'Scaled values')
plot_financial_graph(portfolio_df[['Date', 'Value of Portfolio']], 'Total value of portfolio')
plot_financial_graph(portfolio_df.drop(columns = ['Value of Portfolio','Daily pct change']), 'Raw investment amounts')
plot_financial_graph(portfolio_df[['Date','Daily pct change']], 'Daily pct change')

# %%
initial_investment = 1000000
portfolio_metrics = simulation_engine(weights, initial_investment)

print('Expected Portfolio Annual Return = {:.2f}%'.format(portfolio_metrics[0] * 100))
print('Portfolio Standard Deviation (Volatility) = {:.2f}%'.format(portfolio_metrics[1] * 100))
print('Sharpe Ratio = {:.2f}'.format(portfolio_metrics[2]))
print('Portfolio Final Value = ${:.2f}'.format(portfolio_metrics[3]))
print('Return on Investment = {:.2f}%'.format(portfolio_metrics[4]))
# Out:
# Expected Portfolio Annual Return = 16.97%
# Portfolio Standard Deviation (Volatility) = 18.62%
# Sharpe Ratio = -0.02
# Portfolio Final Value = $3400959.89
# Return on Investment = 240.10%

# %%
# Set the number of simulation runs
sim_runs = 100
initial_investment = 1000000

# Placeholder to store all weights
weights_runs = np.zeros((sim_runs, n))

# Placeholder to store all Sharpe ratios
sharpe_ratio_runs = np.zeros(sim_runs)

# Placeholder to store all expected returns
expected_portfolio_returns_runs = np.zeros(sim_runs)

# Placeholder to store all volatility values
volatility_runs = np.zeros(sim_runs)

# Placeholder to store all returns on investment
return_on_investment_runs = np.zeros(sim_runs)

# Placeholder to store all final portfolio values
final_value_runs = np.zeros(sim_runs)

for i in range(sim_runs):
    # Generate random weights 
    weights = random_weight_generator(n)
    # Store the weights
    weights_runs[i,:] = weights
    
    # Call "simulation_engine" function and store Sharpe ratio, return and volatility
    # Note that asset allocation is performed using the "asset_allocation" function  
    expected_portfolio_returns_runs[i], volatility_runs[i], sharpe_ratio_runs[i], final_value_runs[i], return_on_investment_runs[i] = simulation_engine(weights, initial_investment)
    print("Simulation Run = {}".format(i))   
    print("Weights = {}, Final Value = ${:.2f}, Sharpe Ratio = {:.2f}".format(weights_runs[i].round(3), final_value_runs[i], sharpe_ratio_runs[i]))   
    print('\n')
# Out:
# Simulation Run = 0
# Weights = [0.133 0.015 0.099 0.045 0.123 0.203 0.199 0.025 0.081 0.078], Final Value = $3236342.33, Sharpe Ratio = -0.04
#
#
# Simulation Run = 1
# Weights = [0.096 0.168 0.03  0.059 0.114 0.136 0.168 0.122 0.091 0.016], Final Value = $3041793.26, Sharpe Ratio = -0.02
#
#
# Simulation Run = 2
# Weights = [0.05  0.028 0.153 0.006 0.188 0.083 0.016 0.157 0.176 0.142], Final Value = $3186703.85, Sharpe Ratio = -0.03
#
#
# Simulation Run = 3
# Weights = [0.009 0.086 0.085 0.06  0.132 0.139 0.185 0.051 0.107 0.147], Final Value = $3011539.99, Sharpe Ratio = -0.05
#
#
# Simulation Run = 4
# Weights = [0.169 0.154 0.015 0.154 0.133 0.11  0.117 0.102 0.017 0.029], Final Value = $3172537.01, Sharpe Ratio = -0.01
#
#
# Simulation Run = 5
# Weights = [0.112 0.162 0.205 0.042 0.09  0.085 0.033 0.142 0.103 0.027], Final Value = $3550332.47, Sharpe Ratio = -0.00
#
#
# Simulation Run = 6
# Weights = [0.174 0.114 0.154 0.133 0.109 0.021 0.002 0.049 0.069 0.177], Final Value = $3532739.62, Sharpe Ratio = -0.02
#
#
# Simulation Run = 7
# Weights = [0.064 0.107 0.001 0.153 0.138 0.017 0.075 0.152 0.158 0.136], Final Value = $2849535.41, Sharpe Ratio = -0.04
#
#
# Simulation Run = 8
# Weights = [0.118 0.098 0.126 0.112 0.028 0.078 0.122 0.111 0.068 0.139], Final Value = $3274506.85, Sharpe Ratio = -0.03
#
#
# Simulation Run = 9
# Weights = [0.193 0.111 0.174 0.154 0.009 0.01  0.105 0.053 0.099 0.091], Final Value = $3608306.77, Sharpe Ratio = -0.01
#
#
# Simulation Run = 10
# Weights = [0.055 0.1   0.115 0.103 0.157 0.047 0.111 0.025 0.159 0.128], Final Value = $3236713.96, Sharpe Ratio = -0.04
#
#
# Simulation Run = 11
# Weights = [0.039 0.188 0.168 0.105 0.12  0.041 0.122 0.064 0.143 0.01 ], Final Value = $3423257.28, Sharpe Ratio = -0.01
#
#
# Simulation Run = 12
# Weights = [0.166 0.104 0.083 0.095 0.077 0.095 0.127 0.026 0.127 0.1  ], Final Value = $3293035.15, Sharpe Ratio = -0.03
#
#
# Simulation Run = 13
# Weights = [0.085 0.005 0.048 0.189 0.173 0.054 0.123 0.018 0.177 0.127], Final Value = $3056285.34, Sharpe Ratio = -0.05
#
#
# Simulation Run = 14
# Weights = [0.04  0.167 0.086 0.096 0.102 0.052 0.165 0.069 0.137 0.086], Final Value = $3132517.15, Sharpe Ratio = -0.03
#
#
# Simulation Run = 15
# Weights = [0.122 0.055 0.08  0.057 0.07  0.074 0.153 0.188 0.052 0.15 ], Final Value = $3088957.94, Sharpe Ratio = -0.02
#
#
# Simulation Run = 16
# Weights = [0.051 0.165 0.029 0.168 0.133 0.117 0.013 0.07  0.13  0.125], Final Value = $2971288.31, Sharpe Ratio = -0.05
#
#
# Simulation Run = 17
# Weights = [0.182 0.132 0.156 0.167 0.055 0.063 0.025 0.068 0.137 0.014], Final Value = $3555838.91, Sharpe Ratio = -0.01
#
#
# Simulation Run = 18
# Weights = [0.052 0.049 0.114 0.156 0.016 0.101 0.095 0.161 0.151 0.105], Final Value = $3055212.42, Sharpe Ratio = -0.04
#
#
# Simulation Run = 19
# Weights = [0.117 0.119 0.033 0.078 0.075 0.092 0.129 0.114 0.137 0.106], Final Value = $3012870.38, Sharpe Ratio = -0.04
#
#
# Simulation Run = 20
# Weights = [0.175 0.157 0.106 0.077 0.136 0.022 0.123 0.003 0.009 0.191], Final Value = $3469586.16, Sharpe Ratio = -0.01
#
#
# Simulation Run = 21
# Weights = [0.002 0.132 0.167 0.181 0.17  0.001 0.039 0.055 0.117 0.138], Final Value = $3339396.58, Sharpe Ratio = -0.03
#
#
# Simulation Run = 22
# Weights = [0.153 0.036 0.156 0.105 0.096 0.066 0.12  0.049 0.148 0.072], Final Value = $3452368.72, Sharpe Ratio = -0.02
#
#
# Simulation Run = 23
# Weights = [0.099 0.117 0.039 0.164 0.102 0.012 0.185 0.183 0.012 0.087], Final Value = $3061797.41, Sharpe Ratio = -0.01
#
#
# Simulation Run = 24
# Weights = [0.142 0.166 0.077 0.125 0.038 0.056 0.14  0.16  0.055 0.041], Final Value = $3234282.14, Sharpe Ratio = -0.01
#
#
# Simulation Run = 25
# Weights = [0.061 0.087 0.201 0.019 0.14  0.041 0.015 0.163 0.032 0.242], Final Value = $3379051.52, Sharpe Ratio = -0.02
#
#
# Simulation Run = 26
# Weights = [0.076 0.165 0.114 0.053 0.017 0.069 0.156 0.109 0.141 0.1  ], Final Value = $3189957.84, Sharpe Ratio = -0.03
#
#
# Simulation Run = 27
# Weights = [0.041 0.216 0.183 0.056 0.111 0.033 0.006 0.223 0.098 0.032], Final Value = $3380381.05, Sharpe Ratio = 0.01
#
#
# Simulation Run = 28
# Weights = [0.156 0.138 0.032 0.013 0.067 0.073 0.142 0.18  0.047 0.153], Final Value = $3047725.31, Sharpe Ratio = -0.02
#
#
# Simulation Run = 29
# Weights = [0.012 0.028 0.147 0.091 0.126 0.029 0.152 0.144 0.142 0.127], Final Value = $3144762.81, Sharpe Ratio = -0.03
#
#
# Simulation Run = 30
# Weights = [0.122 0.144 0.136 0.122 0.142 0.034 0.033 0.118 0.102 0.046], Final Value = $3419936.23, Sharpe Ratio = -0.01
#
#
# Simulation Run = 31
# Weights = [0.107 0.039 0.03  0.015 0.074 0.116 0.004 0.229 0.186 0.199], Final Value = $2799138.64, Sharpe Ratio = -0.04
#
#
# Simulation Run = 32
# Weights = [0.12  0.033 0.055 0.158 0.126 0.164 0.099 0.053 0.132 0.06 ], Final Value = $3100689.56, Sharpe Ratio = -0.04
#
#
# Simulation Run = 33
# Weights = [0.058 0.076 0.053 0.144 0.135 0.187 0.001 0.169 0.02  0.156], Final Value = $2941329.60, Sharpe Ratio = -0.04
#
#
# Simulation Run = 34
# Weights = [0.12  0.068 0.138 0.197 0.004 0.054 0.055 0.14  0.096 0.127], Final Value = $3283632.16, Sharpe Ratio = -0.03
#
#
# Simulation Run = 35
# Weights = [0.157 0.007 0.066 0.05  0.087 0.17  0.07  0.119 0.129 0.146], Final Value = $3068863.47, Sharpe Ratio = -0.04
#
#
# Simulation Run = 36
# Weights = [0.031 0.159 0.145 0.034 0.162 0.002 0.011 0.174 0.224 0.057], Final Value = $3230776.36, Sharpe Ratio = -0.01
#
#
# Simulation Run = 37
# Weights = [0.025 0.122 0.147 0.179 0.162 0.054 0.005 0.12  0.117 0.069], Final Value = $3278743.20, Sharpe Ratio = -0.02
#
#
# Simulation Run = 38
# Weights = [0.089 0.033 0.136 0.141 0.147 0.171 0.093 0.045 0.132 0.016], Final Value = $3310659.68, Sharpe Ratio = -0.03
#
#
# Simulation Run = 39
# Weights = [0.096 0.084 0.131 0.072 0.076 0.097 0.031 0.163 0.087 0.163], Final Value = $3203135.40, Sharpe Ratio = -0.03
#
#
# Simulation Run = 40
# Weights = [0.164 0.022 0.013 0.151 0.128 0.125 0.048 0.22  0.064 0.066], Final Value = $2972663.19, Sharpe Ratio = -0.02
#
#
# Simulation Run = 41
# Weights = [0.149 0.005 0.13  0.143 0.094 0.182 0.048 0.048 0.036 0.166], Final Value = $3321826.71, Sharpe Ratio = -0.04
#
#
# Simulation Run = 42
# Weights = [0.191 0.09  0.115 0.193 0.08  0.015 0.218 0.023 0.051 0.023], Final Value = $3519660.77, Sharpe Ratio = -0.00
#
#
# Simulation Run = 43
# Weights = [0.007 0.169 0.159 0.116 0.104 0.089 0.025 0.156 0.064 0.111], Final Value = $3243202.33, Sharpe Ratio = -0.02
#
#
# Simulation Run = 44
# Weights = [0.115 0.178 0.006 0.19  0.073 0.05  0.154 0.039 0.101 0.093], Final Value = $3060642.53, Sharpe Ratio = -0.03
#
#
# Simulation Run = 45
# Weights = [0.035 0.148 0.142 0.16  0.132 0.066 0.063 0.049 0.018 0.186], Final Value = $3308689.50, Sharpe Ratio = -0.03
#
#
# Simulation Run = 46
# Weights = [0.007 0.104 0.148 0.137 0.003 0.106 0.147 0.172 0.059 0.118], Final Value = $3118488.71, Sharpe Ratio = -0.03
#
#
# Simulation Run = 47
# Weights = [0.028 0.168 0.117 0.133 0.202 0.    0.047 0.099 0.059 0.146], Final Value = $3255049.68, Sharpe Ratio = -0.02
#
#
# Simulation Run = 48
# Weights = [0.194 0.098 0.149 0.029 0.164 0.068 0.058 0.102 0.003 0.135], Final Value = $3539608.77, Sharpe Ratio = -0.00
#
#
# Simulation Run = 49
# Weights = [0.126 0.132 0.123 0.037 0.099 0.054 0.157 0.039 0.159 0.074], Final Value = $3363441.81, Sharpe Ratio = -0.02
#
#
# Simulation Run = 50
# Weights = [0.145 0.099 0.088 0.14  0.151 0.121 0.072 0.012 0.094 0.079], Final Value = $3328384.68, Sharpe Ratio = -0.03
#
#
# Simulation Run = 51
# Weights = [0.166 0.077 0.094 0.117 0.154 0.091 0.116 0.124 0.039 0.021], Final Value = $3346124.04, Sharpe Ratio = -0.01
#
#
# Simulation Run = 52
# Weights = [0.113 0.13  0.033 0.141 0.09  0.072 0.137 0.125 0.109 0.049], Final Value = $3060870.52, Sharpe Ratio = -0.03
#
#
# Simulation Run = 53
# Weights = [0.123 0.076 0.05  0.134 0.033 0.18  0.036 0.03  0.144 0.193], Final Value = $3023898.91, Sharpe Ratio = -0.07
#
#
# Simulation Run = 54
# Weights = [0.116 0.14  0.173 0.003 0.128 0.076 0.079 0.203 0.049 0.034], Final Value = $3443709.11, Sharpe Ratio = 0.01
#
#
# Simulation Run = 55
# Weights = [0.084 0.101 0.022 0.044 0.028 0.082 0.093 0.279 0.011 0.255], Final Value = $2778832.62, Sharpe Ratio = -0.03
#
#
# Simulation Run = 56
# Weights = [0.209 0.04  0.182 0.006 0.033 0.034 0.157 0.056 0.156 0.126], Final Value = $3563548.01, Sharpe Ratio = -0.01
#
#
# Simulation Run = 57
# Weights = [0.022 0.259 0.084 0.049 0.013 0.137 0.235 0.122 0.067 0.011], Final Value = $3092858.16, Sharpe Ratio = -0.01
#
#
# Simulation Run = 58
# Weights = [0.045 0.119 0.038 0.114 0.141 0.075 0.071 0.138 0.172 0.087], Final Value = $2929006.94, Sharpe Ratio = -0.04
#
#
# Simulation Run = 59
# Weights = [0.058 0.083 0.045 0.165 0.111 0.121 0.079 0.16  0.111 0.067], Final Value = $2945054.81, Sharpe Ratio = -0.04
#
#
# Simulation Run = 60
# Weights = [0.153 0.031 0.163 0.094 0.15  0.108 0.078 0.151 0.06  0.011], Final Value = $3468603.31, Sharpe Ratio = -0.00
#
#
# Simulation Run = 61
# Weights = [0.135 0.202 0.137 0.037 0.119 0.035 0.019 0.039 0.166 0.112], Final Value = $3451660.98, Sharpe Ratio = -0.02
#
#
# Simulation Run = 62
# Weights = [0.034 0.137 0.06  0.098 0.124 0.055 0.138 0.108 0.158 0.09 ], Final Value = $3007180.55, Sharpe Ratio = -0.03
#
#
# Simulation Run = 63
# Weights = [0.061 0.134 0.183 0.054 0.003 0.146 0.027 0.019 0.158 0.214], Final Value = $3319692.87, Sharpe Ratio = -0.05
#
#
# Simulation Run = 64
# Weights = [0.143 0.145 0.089 0.113 0.166 0.026 0.09  0.041 0.173 0.014], Final Value = $3364494.83, Sharpe Ratio = -0.01
#
#
# Simulation Run = 65
# Weights = [0.021 0.123 0.104 0.061 0.138 0.102 0.079 0.142 0.114 0.116], Final Value = $3072900.30, Sharpe Ratio = -0.03
#
#
# Simulation Run = 66
# Weights = [0.121 0.1   0.059 0.105 0.144 0.113 0.135 0.121 0.033 0.068], Final Value = $3156960.68, Sharpe Ratio = -0.02
#
#
# Simulation Run = 67
# Weights = [0.001 0.086 0.136 0.027 0.068 0.172 0.13  0.19  0.11  0.08 ], Final Value = $3040559.89, Sharpe Ratio = -0.03
#
#
# Simulation Run = 68
# Weights = [0.115 0.062 0.065 0.089 0.109 0.01  0.026 0.115 0.194 0.215], Final Value = $3051056.12, Sharpe Ratio = -0.04
#
#
# Simulation Run = 69
# Weights = [0.012 0.182 0.161 0.182 0.101 0.061 0.003 0.116 0.097 0.085], Final Value = $3305189.52, Sharpe Ratio = -0.02
#
#
# Simulation Run = 70
# Weights = [0.047 0.208 0.097 0.104 0.061 0.054 0.19  0.102 0.098 0.039], Final Value = $3194783.87, Sharpe Ratio = -0.01
#
#
# Simulation Run = 71
# Weights = [0.22  0.089 0.155 0.052 0.019 0.045 0.06  0.187 0.008 0.165], Final Value = $3476834.21, Sharpe Ratio = 0.00
#
#
# Simulation Run = 72
# Weights = [0.047 0.145 0.145 0.184 0.146 0.067 0.161 0.01  0.086 0.009], Final Value = $3415094.62, Sharpe Ratio = -0.01
#
#
# Simulation Run = 73
# Weights = [0.197 0.247 0.1   0.147 0.05  0.013 0.095 0.048 0.019 0.085], Final Value = $3520712.39, Sharpe Ratio = 0.00
#
#
# Simulation Run = 74
# Weights = [0.098 0.192 0.198 0.199 0.006 0.056 0.103 0.058 0.072 0.018], Final Value = $3590348.63, Sharpe Ratio = -0.00
#
#
# Simulation Run = 75
# Weights = [0.089 0.037 0.145 0.095 0.068 0.135 0.024 0.114 0.143 0.15 ], Final Value = $3210887.45, Sharpe Ratio = -0.04
#
#
# Simulation Run = 76
# Weights = [0.011 0.17  0.071 0.132 0.102 0.015 0.156 0.151 0.113 0.08 ], Final Value = $3023415.61, Sharpe Ratio = -0.02
#
#
# Simulation Run = 77
# Weights = [0.046 0.148 0.006 0.079 0.06  0.059 0.163 0.102 0.154 0.184], Final Value = $2813625.40, Sharpe Ratio = -0.05
#
#
# Simulation Run = 78
# Weights = [0.011 0.016 0.191 0.081 0.197 0.085 0.117 0.185 0.117 0.   ], Final Value = $3300714.84, Sharpe Ratio = -0.01
#
#
# Simulation Run = 79
# Weights = [0.083 0.06  0.073 0.084 0.069 0.105 0.132 0.076 0.169 0.148], Final Value = $3033265.78, Sharpe Ratio = -0.05
#
#
# Simulation Run = 80
# Weights = [0.052 0.001 0.213 0.1   0.137 0.036 0.135 0.072 0.155 0.099], Final Value = $3439171.22, Sharpe Ratio = -0.02
#
#
# Simulation Run = 81
# Weights = [0.07  0.123 0.092 0.17  0.074 0.062 0.163 0.042 0.158 0.047], Final Value = $3195514.80, Sharpe Ratio = -0.03
#
#
# Simulation Run = 82
# Weights = [0.109 0.132 0.132 0.019 0.052 0.045 0.109 0.055 0.159 0.188], Final Value = $3286787.48, Sharpe Ratio = -0.03
#
#
# Simulation Run = 83
# Weights = [0.205 0.198 0.005 0.109 0.033 0.108 0.124 0.037 0.118 0.065], Final Value = $3165748.04, Sharpe Ratio = -0.03
#
#
# Simulation Run = 84
# Weights = [0.096 0.011 0.014 0.096 0.019 0.058 0.178 0.274 0.159 0.095], Final Value = $2754771.04, Sharpe Ratio = -0.02
#
#
# Simulation Run = 85
# Weights = [0.129 0.161 0.024 0.083 0.001 0.144 0.108 0.101 0.145 0.104], Final Value = $2985863.50, Sharpe Ratio = -0.04
#
#
# Simulation Run = 86
# Weights = [0.016 0.157 0.043 0.025 0.128 0.133 0.123 0.055 0.121 0.198], Final Value = $2907012.50, Sharpe Ratio = -0.05
#
#
# Simulation Run = 87
# Weights = [0.053 0.084 0.101 0.151 0.055 0.067 0.184 0.101 0.07  0.134], Final Value = $3121990.05, Sharpe Ratio = -0.03
#
#
# Simulation Run = 88
# Weights = [0.094 0.146 0.168 0.143 0.068 0.122 0.112 0.02  0.113 0.014], Final Value = $3480028.59, Sharpe Ratio = -0.02
#
#
# Simulation Run = 89
# Weights = [0.009 0.157 0.03  0.148 0.12  0.096 0.157 0.095 0.148 0.041], Final Value = $2913066.37, Sharpe Ratio = -0.04
#
#
# Simulation Run = 90
# Weights = [0.092 0.051 0.068 0.167 0.176 0.019 0.102 0.057 0.128 0.139], Final Value = $3147481.91, Sharpe Ratio = -0.04
#
#
# Simulation Run = 91
# Weights = [0.003 0.123 0.094 0.161 0.113 0.075 0.081 0.091 0.112 0.147], Final Value = $3050618.27, Sharpe Ratio = -0.04
#
#
# Simulation Run = 92
# Weights = [0.1   0.073 0.1   0.106 0.126 0.047 0.174 0.052 0.214 0.009], Final Value = $3246672.52, Sharpe Ratio = -0.02
#
#
# Simulation Run = 93
# Weights = [0.066 0.165 0.076 0.002 0.144 0.122 0.147 0.092 0.041 0.145], Final Value = $3118817.77, Sharpe Ratio = -0.03
#
#
# Simulation Run = 94
# Weights = [0.203 0.168 0.103 0.1   0.004 0.089 0.015 0.046 0.125 0.147], Final Value = $3381448.30, Sharpe Ratio = -0.03
#
#
# Simulation Run = 95
# Weights = [0.118 0.179 0.07  0.05  0.019 0.023 0.052 0.168 0.117 0.205], Final Value = $3081931.64, Sharpe Ratio = -0.03
#
#
# Simulation Run = 96
# Weights = [0.128 0.189 0.099 0.124 0.003 0.068 0.058 0.055 0.013 0.262], Final Value = $3263560.49, Sharpe Ratio = -0.04
#
#
# Simulation Run = 97
# Weights = [0.083 0.087 0.039 0.092 0.137 0.043 0.218 0.207 0.02  0.074], Final Value = $3002910.83, Sharpe Ratio = -0.01
#
#
# Simulation Run = 98
# Weights = [0.093 0.101 0.006 0.154 0.035 0.1   0.126 0.148 0.15  0.086], Final Value = $2860830.41, Sharpe Ratio = -0.04
#
#
# Simulation Run = 99
# Weights = [0.082 0.109 0.134 0.118 0.112 0.138 0.016 0.089 0.085 0.117], Final Value = $3276051.90, Sharpe Ratio = -0.04

# %%
# List all Sharpe ratios generated from the simulation
sharpe_ratio_runs

# Return the index of the maximum Sharpe ratio (Best simulation run)
sharpe_ratio_runs.argmax()

# Return the maximum Sharpe ratio value
sharpe_ratio_runs.max()

# Obtain the portfolio weights that correspond to the maximum Sharpe ratio (Golden set of weights!)
weights_runs[sharpe_ratio_runs.argmax(),:]
# Out:
# array([0.11599332, 0.13969365, 0.17252662, 0.00293608, 0.12802206,
#        0.07562636, 0.07933945, 0.2026062 , 0.04881246, 0.03444379])

# %%
# Return Sharpe ratio, volatility corresponding to the best weights allocation (maximum Sharpe ratio)
optimal_portfolio_return, optimal_volatility, optimal_sharpe_ratio, highest_final_value, optimal_return_on_investment = simulation_engine(weights_runs[sharpe_ratio_runs.argmax(),:],initial_investment)
print('Best Portfolio Metrics Based on {} Monte Carlo Simulation Runs:'.format(sim_runs))
print('- Portfolio Expected Annual Return = {:.2f}%'.format(optimal_portfolio_return * 100))
print('- Portfolio Standard Deviation (Volatility) = {:.2f}%'.format(optimal_volatility * 100))
print('- Sharpe Ratio = {:.2f}'.format(optimal_sharpe_ratio))
print('- Final Value = ${:.2f}'.format(highest_final_value))
print('- Return on Investment = {:.2f}%'.format(optimal_return_on_investment))
# Out:
# Best Portfolio Metrics Based on 100 Monte Carlo Simulation Runs:
# - Portfolio Expected Annual Return = 17.67%
# - Portfolio Standard Deviation (Volatility) = 20.90%
# - Sharpe Ratio = 0.01
# - Final Value = $3443709.11
# - Return on Investment = 244.37%
